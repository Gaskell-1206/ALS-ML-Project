# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %%
from google.colab import drive # this is how I loaded the data in today. run this code and create a shortcut in your google drive for this folder 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## familyHistory

# %%
familyHistory = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/familyHistory1.csv")

# %%
familyHistory
# Out:
#       subject_id  NeuroDisease  ...  FamilyMember_2nd  FamilyMember_3rd
# 0            348             0  ...                 0                 0
# 1           1064             0  ...                 0                 0
# 2           3809             1  ...                 0                 0
# 3           4877             0  ...                 0                 0
# 4           5918             0  ...                 0                 0
# ...          ...           ...  ...               ...               ...
# 1002      996808             0  ...                 0                 0
# 1003      996997             1  ...                 0                 0
# 1004      998019             1  ...                 0                 0
# 1005      998047             1  ...                 0                 0
# 1006      998773             1  ...                 0                 0
#
# [1007 rows x 11 columns]

# %%
familyHistory.describe()
# Out:
#           subject_id  NeuroDisease  ...  FamilyMember_2nd  FamilyMember_3rd
# count    1007.000000   1007.000000  ...       1007.000000       1007.000000
# mean   494935.033764      0.561072  ...          0.060576          0.009930
# std    292644.969478      0.496503  ...          0.238669          0.099205
# min       348.000000      0.000000  ...          0.000000          0.000000
# 25%    238119.500000      0.000000  ...          0.000000          0.000000
# 50%    485915.000000      1.000000  ...          0.000000          0.000000
# 75%    752540.500000      1.000000  ...          0.000000          0.000000
# max    998773.000000      1.000000  ...          1.000000          1.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# ## alsHistory

# %%
alsHistory = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/AlsHistory1.csv")

# %%
alsHistory
# Out:
#       subject_id  SiteOfOnset  ...  SymGAIT_CHANGES  SymOnsetDelta
# 0             89            1  ...                0            NaN
# 1            329            1  ...                0            NaN
# 2            348            3  ...                0            NaN
# 3            406            1  ...                0            NaN
# 4            411            2  ...                0            NaN
# ...          ...          ...  ...              ...            ...
# 9388      999823            1  ...                0            NaN
# 9389      999863            1  ...                0            NaN
# 9390      999880            1  ...                0            NaN
# 9391      999929            1  ...                0            NaN
# 9392      999990            1  ...                0            NaN
#
# [9393 rows x 14 columns]

# %%
alsHistory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9393 entries, 0 to 9392
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   subject_id          9393 non-null   int64
#  1   SiteOfOnset         9393 non-null   int64
#  2   OnsetDelta          4660 non-null   float64
#  3   SymWEAKNESS         9393 non-null   int64
#  4   SymSpeech           9393 non-null   int64
#  5   SymCramps           9393 non-null   int64
#  6   SymFasciculations   9393 non-null   int64
#  7   SymAtrophy          9393 non-null   int64
#  8   SymOTHER            9393 non-null   int64
#  9   SymSwallowing       9393 non-null   int64
#  10  SymStiffness        9393 non-null   int64
#  11  SymSENSORY_CHANGES  9393 non-null   int64
#  12  SymGAIT_CHANGES     9393 non-null   int64
#  13  SymOnsetDelta       2214 non-null   float64
# dtypes: float64(2), int64(12)
# memory usage: 1.0 MB

# %%
alsHistory.describe()
# Out:
#           subject_id  SiteOfOnset  ...  SymGAIT_CHANGES  SymOnsetDelta
# count    9393.000000  9393.000000  ...      9393.000000    2214.000000
# mean   501402.962419     1.374321  ...         0.002449    -755.364950
# std    291401.525709     0.692646  ...         0.049426     627.935687
# min        89.000000     0.000000  ...         0.000000  -11382.000000
# 25%    249849.000000     1.000000  ...         0.000000    -961.000000
# 50%    505903.000000     1.000000  ...         0.000000    -587.000000
# 75%    753843.000000     2.000000  ...         0.000000    -369.000000
# max    999990.000000     5.000000  ...         1.000000     -16.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# ## labs

# %%
labs = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/labs1.csv")

# %%
labs
# Out:
#       subject_id  ALTSGPT_ValueAve  ...  Neutrophils_TestNum  Neutrophils_Duration
# 0            329         32.000000  ...                  NaN                   NaN
# 1            348         40.750000  ...                  NaN                   NaN
# 2            533         21.000000  ...                  2.0                  91.0
# 3            649         17.000000  ...                  NaN                   NaN
# 4            708         18.750000  ...                  NaN                   NaN
# ...          ...               ...  ...                  ...                   ...
# 8250      999761         44.500000  ...                  NaN                   NaN
# 8251      999863         26.250000  ...                  NaN                   NaN
# 8252      999880         23.333333  ...                  NaN                   NaN
# 8253      999929         73.500000  ...                  NaN                   NaN
# ...

# %%
labs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8255 entries, 0 to 8254
# Columns: 211 entries, subject_id to Neutrophils_Duration
# dtypes: float64(210), int64(1)
# memory usage: 13.3 MB

# %%
labs.describe()
# Out:
#           subject_id  ...  Neutrophils_Duration
# count    8255.000000  ...           3630.000000
# mean   501712.451605  ...             50.008815
# std    289946.933506  ...             36.518146
# min       329.000000  ...              0.000000
# 25%    250761.500000  ...              0.000000
# 50%    507993.000000  ...             63.000000
# 75%    751997.000000  ...             83.000000
# max    999990.000000  ...            202.000000
#
# [8 rows x 211 columns]

# %% [markdown]
# ## demography

# %%
demography = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/demo_clean.csv")

# %%
demography
# Out:
#       subject_id   Age  sex_male  ...  Height_cm  BMI_baseline  race_missing
# 0             89   NaN         1  ...        NaN           NaN             0
# 1            329  38.0         0  ...        NaN           NaN             0
# 2            348  52.0         0  ...      163.0     44.713764             0
# 3            406   NaN         1  ...        NaN           NaN             0
# 4            411   NaN         1  ...        NaN           NaN             0
# ...          ...   ...       ...  ...        ...           ...           ...
# 9635      999761  62.0         1  ...        NaN           NaN             0
# 9636      999823  54.9         1  ...      179.0     21.878219             0
# 9637      999880  51.0         1  ...        NaN           NaN             0
# 9638      999929  56.0         1  ...        NaN           NaN             0
# 9639      999990  59.5         0  ...      160.0     22.187500             0
#
# [9640 rows x 11 columns]

# %%
demography.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9640 entries, 0 to 9639
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   subject_id        9640 non-null   int64
#  1   Age               6872 non-null   float64
#  2   sex_male          9640 non-null   int64
#  3   race_white        9640 non-null   int64
#  4   race_black        9640 non-null   int64
#  5   race_othergrps    9640 non-null   int64
#  6   race_asiangrp     9640 non-null   int64
#  7   study_arm_active  9640 non-null   int64
#  8   Height_cm         3624 non-null   float64
#  9   BMI_baseline      3468 non-null   float64
#  10  race_missing      9640 non-null   int64
# dtypes: float64(3), int64(8)
# memory usage: 828.6 KB

# %% [markdown]
# ## vital

# %%
vital = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/vital_clean2.csv")

# %%
vital
# Out:
#       subject_id  Blood_Pressure_Diastolic_mean  ...  Weight_kg_slope  BMI_slope
# 0            329                            NaN  ...        -0.088889  -0.035833
# 1            348                      88.250000  ...         0.060656   0.022830
# 2            533                      83.000000  ...        -0.005495  -0.002410
# 3            586                      70.000000  ...              NaN        NaN
# 4            649                      78.666667  ...         0.011475   0.004656
# ...          ...                            ...  ...              ...        ...
# 7637      635367                            NaN  ...              NaN        NaN
# 7638      900264                            NaN  ...              NaN        NaN
# 7639      922308                            NaN  ...              NaN        NaN
# 7640      379114                            NaN  ...              NaN        NaN
# 7641       49075                            NaN  ...              NaN        NaN
#
# ...

# %%
vital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7642 entries, 0 to 7641
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   subject_id                      7642 non-null   int64
#  1   Blood_Pressure_Diastolic_mean   6293 non-null   float64
#  2   Blood_Pressure_Systolic_mean    6293 non-null   float64
#  3   Pulse_mean                      6289 non-null   float64
#  4   Respiratory_Rate_mean           5837 non-null   float64
#  5   Temperature_mean                3609 non-null   float64
#  6   Weight_kg_mean                  7564 non-null   float64
#  7   BMI_mean                        6646 non-null   float64
#  8   Blood_Pressure_Diastolic_sd     5715 non-null   float64
#  9   Blood_Pressure_Systolic_sd      5715 non-null   float64
#  10  Pulse_sd                        5707 non-null   float64
#  11  Respiratory_Rate_sd             5328 non-null   float64
# ...

# %% [markdown]
# ## Riluzole

# %%
Riluzole = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/Riluzole_cleaned.csv")

# %%
Riluzole = Riluzole.drop(columns="Unnamed: 0")

# %%
Riluzole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8817 entries, 0 to 8816
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             8817 non-null   int64
#  1   Subject_used_Riluzole  8817 non-null   int64
#  2   Riluzole_use_Delta     8816 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 206.8 KB

# %%
Riluzole.describe()
# Out:
#           subject_id  Subject_used_Riluzole  Riluzole_use_Delta
# count    8817.000000            8817.000000         8816.000000
# mean   501404.267438               0.788590            0.785844
# std    290498.647930               0.408331            9.812361
# min        89.000000               0.000000         -105.000000
# 25%    249849.000000               1.000000            0.000000
# 50%    508550.000000               1.000000            0.000000
# 75%    751799.000000               1.000000            0.000000
# max    999990.000000               1.000000          366.000000

# %% [markdown]
# ## fvc

# %%
fvc = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/fvc.csv")

# %%
fvc = fvc.drop(columns='Unnamed: 0')
fvc
# Out:
#       subject_id  ...  fvc_liters_SlopeDeltaSlope
# 0             89  ...                    0.000000
# 1            329  ...                   -0.000253
# 2            406  ...                    0.000000
# 3            411  ...                    0.000000
# 4            533  ...                    0.000000
# ...          ...  ...                         ...
# 7352      999482  ...                   -0.000418
# 7353      999823  ...                   -0.000122
# 7354      999863  ...                    0.000000
# 7355      999880  ...                    0.000095
# 7356      999990  ...                   -0.000394
#
# [7357 rows x 23 columns]

# %%
fvc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7357 entries, 0 to 7356
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   subject_id                  7357 non-null   int64
#  1   fvc_liters_ValueMax         7357 non-null   float64
#  2   fvc_liters_ValueMin         7357 non-null   float64
#  3   fvc_liters_ValueLast        7357 non-null   float64
#  4   fvc_liters_ValueMean        7357 non-null   float64
#  5   fvc_liters_ValueNumber      7357 non-null   int64
#  6   fvc_liters_valueSum         7357 non-null   float64
#  7   fvc_liters_DeltaFirst       7357 non-null   float64
#  8   fvc_liters_DeltaLast        7357 non-null   float64
#  9   fvc_liters_ValueMeanSquare  7357 non-null   float64
#  10  fvc_liters_ValueStd         7357 non-null   float64
#  11  fvc_liters_DeltaSlope       7357 non-null   float64
#  12  fvc_liters_SlopeMax         7357 non-null   float64
# ...

# %%
fvc.describe()
# Out:
#           subject_id  ...  fvc_liters_SlopeDeltaSlope
# count    7357.000000  ...                 7357.000000
# mean   503842.902542  ...                   -0.000017
# std    291221.459215  ...                    0.001249
# min        89.000000  ...                   -0.054237
# 25%    252453.000000  ...                   -0.000075
# 50%    509377.000000  ...                    0.000000
# 75%    757731.000000  ...                    0.000052
# max    999990.000000  ...                    0.055381
#
# [8 rows x 23 columns]

# %%
fvc_1 = fvc.drop(columns='subject_id')
fvc_1
# Out:
#       fvc_liters_ValueMax  ...  fvc_liters_SlopeDeltaSlope
# 0                    2.89  ...                    0.000000
# 1                    2.79  ...                   -0.000253
# 2                    3.69  ...                    0.000000
# 3                    2.44  ...                    0.000000
# 4                    1.92  ...                    0.000000
# ...                   ...  ...                         ...
# 7352                 4.40  ...                   -0.000418
# 7353                 4.72  ...                   -0.000122
# 7354                 1.27  ...                    0.000000
# 7355                 1.97  ...                    0.000095
# 7356                 2.70  ...                   -0.000394
#
# [7357 rows x 22 columns]

# %% [markdown]
# ## svc

# %%
svc = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/svc.csv")

# %%
svc = svc.drop(columns="Unnamed: 0")
svc
# Out:
#      subject_id  ...  svc_liters_SlopeDeltaSlope
# 0           348  ...                    0.000000
# 1          1064  ...                   -0.000500
# 2          4877  ...                    0.000000
# 3          5918  ...                    0.000000
# 4          7799  ...                   -0.000049
# ..          ...  ...                         ...
# 690      995893  ...                    0.000000
# 691      996611  ...                   -0.000585
# 692      996711  ...                    0.000000
# 693      996808  ...                    0.000000
# 694      997090  ...                   -0.000270
#
# [695 rows x 21 columns]

# %%
svc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   subject_id                  695 non-null    int64
#  1   svc_liters_ValueMax         695 non-null    float64
#  2   svc_liters_ValueMin         695 non-null    float64
#  3   svc_liters_ValueLast        695 non-null    float64
#  4   svc_liters_ValueMean        695 non-null    float64
#  5   svc_liters_ValueNumber      695 non-null    int64
#  6   svc_liters_valueSum         695 non-null    float64
#  7   svc_liters_DeltaFirst       695 non-null    float64
#  8   svc_liters_DeltaLast        695 non-null    float64
#  9   svc_liters_ValueMeanSquare  695 non-null    float64
#  10  svc_liters_DeltaSlope       695 non-null    float64
#  11  svc_liters_SlopeMax         695 non-null    float64
#  12  svc_liters_SlopeMin         695 non-null    float64
# ...

# %%
svc.describe()
# Out:
#           subject_id  ...  svc_liters_SlopeDeltaSlope
# count     695.000000  ...                  695.000000
# mean   499804.080576  ...                    0.000024
# std    298170.372282  ...                    0.001710
# min       348.000000  ...                   -0.019417
# 25%    232376.000000  ...                   -0.000388
# 50%    515584.000000  ...                    0.000000
# 75%    758846.500000  ...                    0.000000
# max    997090.000000  ...                    0.014925
#
# [8 rows x 21 columns]

# %% [markdown]
# ## ALSFRS

# %%
ALSFRS_First_3_months = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/alsfrs_cleaned_first_3_months.csv")

ALSFRS_First_3_months
# Out:
#       subject_id  Delta_first_visit  ...  ALSFRS_Total_3_month  slope_first_3_months
# 0            329           0.000000  ...                    30              1.268194
# 1            533           0.000000  ...                    29             -0.334469
# 2            649           0.000000  ...                    36              0.000000
# 3            708           0.000000  ...                    31             -0.668938
# 4           1234           0.000000  ...                    21              0.000000
# ...          ...                ...  ...                   ...                   ...
# 3528      998894           0.000000  ...                    18             -1.268194
# 3529      998908           0.000000  ...                    32             -0.447598
# 3530      999482           0.000000  ...                    34             -1.141375
# 3531      999880           0.000000  ...                    25              0.434810
# ...

# %%
ALSFRS_First_3_months.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3533 entries, 0 to 3532
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   subject_id              3533 non-null   int64
#  1   Delta_first_visit       3533 non-null   float64
#  2   ALSFRS_Total_beginning  3533 non-null   float64
#  3   Delta_3_month           3533 non-null   float64
#  4   ALSFRS_Total_3_month    3533 non-null   int64
#  5   slope_first_3_months    3533 non-null   float64
# dtypes: float64(4), int64(2)
# memory usage: 165.7 KB

# %%
ALSFRS_First_3_months.describe()
# Out:
#           subject_id  ...  slope_first_3_months
# count    3533.000000  ...           3533.000000
# mean   500672.933484  ...             -0.680964
# std    291247.956410  ...              1.710718
# min       329.000000  ...            -13.044286
# 25%    248112.000000  ...             -1.367940
# 50%    501306.000000  ...             -0.490914
# 75%    752997.000000  ...              0.000000
# max    999990.000000  ...             21.740476
#
# [8 rows x 6 columns]

# %%
ALSFRS_following_9_months = pd.read_csv("/content/drive/MyDrive/ML Project/Cleaned data/alsfrs_cleaned_following_9_months.csv")

ALSFRS_following_9_months
# Out:
#       subject_id  ...  slope_following_9_months
# 0            329  ...                 -1.268194
# 1            533  ...                 -0.966243
# 2            649  ...                 -0.922323
# 3            708  ...                 -0.543512
# 4           1234  ...                 -0.915388
# ...          ...  ...                       ...
# 3528      998894  ...                 -1.504474
# 3529      998908  ...                 -0.856443
# 3530      999482  ...                 -2.051910
# 3531      999880  ...                  0.756190
# 3532      999990  ...                 -1.049540
#
# [3533 rows x 6 columns]

# %%
ALSFRS_following_9_months.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3533 entries, 0 to 3532
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   subject_id                         3533 non-null   int64
#  1   Delta_first_visit_after_3_months   3533 non-null   float64
#  2   ALSFRS_first_visit_after_3_months  3533 non-null   float64
#  3   Delta_last_visit                   3533 non-null   float64
#  4   ALSFRS_last_visit                  3533 non-null   float64
#  5   slope_following_9_months           3533 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 165.7 KB

# %%
ALSFRS_following_9_months.describe()
# Out:
#           subject_id  ...  slope_following_9_months
# count    3533.000000  ...               3533.000000
# mean   500672.933484  ...                 -0.883304
# std    291247.956410  ...                  0.992433
# min       329.000000  ...                -10.870238
# 25%    248112.000000  ...                 -1.275788
# 50%    501306.000000  ...                 -0.711969
# 75%    752997.000000  ...                 -0.272567
# max    999990.000000  ...                  7.609167
#
# [8 rows x 6 columns]

# %% [markdown]
# # Merge data

# %%
# familyHistory.set_index('subject_id',inplace=True)
# alsHistory.set_index('subject_id',inplace=True)
# labs.set_index('subject_id',inplace=True)
# demography.set_index('subject_id',inplace=True)
# vital_baseline.set_index('subject_id',inplace=True)
# Riluzole.set_index('subject_id',inplace=True)
# fvc.set_index('subject_id',inplace=True)
# svc.set_index('subject_id',inplace=True)
# ALSFRS.set_index('subject_id',inplace=True)

# %%
df_all = ALSFRS_following_9_months[['subject_id','slope_following_9_months']].merge(demography, on='subject_id', how='inner')
df_all
# Out:
#       subject_id  slope_following_9_months  ...  BMI_baseline  race_missing
# 0            329                 -1.268194  ...           NaN             0
# 1            649                 -0.922323  ...     29.899793             0
# 2            708                 -0.543512  ...           NaN             0
# 3           1234                 -0.915388  ...     30.857143             0
# 4           2492                 -0.598754  ...     29.759546             0
# ...          ...                       ...  ...           ...           ...
# 3186      998894                 -1.504474  ...     27.041644             0
# 3187      998908                 -0.856443  ...           NaN             0
# 3188      999482                 -2.051910  ...           NaN             0
# 3189      999880                  0.756190  ...           NaN             0
# 3190      999990                 -1.049540  ...     22.187500             0
#
# [3191 rows x 12 columns]

# %%
df_all = df_all.merge(ALSFRS_First_3_months, on='subject_id', how='left')
df_all
# Out:
#       subject_id  ...  slope_first_3_months
# 0            329  ...              1.268194
# 1            649  ...              0.000000
# 2            708  ...             -0.668938
# 3           1234  ...              0.000000
# 4           2492  ...              0.000000
# ...          ...  ...                   ...
# 3186      998894  ...             -1.268194
# 3187      998908  ...             -0.447598
# 3188      999482  ...             -1.141375
# 3189      999880  ...              0.434810
# 3190      999990  ...             -1.630536
#
# [3191 rows x 17 columns]

# %%
df_all = df_all.merge(familyHistory, on='subject_id', how='left')
df_all
# Out:
#       subject_id  slope_following_9_months  ...  FamilyMember_2nd  FamilyMember_3rd
# 0            329                 -1.268194  ...               NaN               NaN
# 1            649                 -0.922323  ...               NaN               NaN
# 2            708                 -0.543512  ...               NaN               NaN
# 3           1234                 -0.915388  ...               NaN               NaN
# 4           2492                 -0.598754  ...               NaN               NaN
# ...          ...                       ...  ...               ...               ...
# 3186      998894                 -1.504474  ...               NaN               NaN
# 3187      998908                 -0.856443  ...               NaN               NaN
# 3188      999482                 -2.051910  ...               NaN               NaN
# 3189      999880                  0.756190  ...               NaN               NaN
# ...

# %%
df_all = df_all.merge(alsHistory, on='subject_id', how='left')
df_all
# Out:
#       subject_id  slope_following_9_months  ...  SymGAIT_CHANGES  SymOnsetDelta
# 0            329                 -1.268194  ...                0            NaN
# 1            649                 -0.922323  ...                0         -341.0
# 2            708                 -0.543512  ...                0            NaN
# 3           1234                 -0.915388  ...                0        -1181.0
# 4           2492                 -0.598754  ...                0            NaN
# ...          ...                       ...  ...              ...            ...
# 3186      998894                 -1.504474  ...                0        -1226.0
# 3187      998908                 -0.856443  ...                0         -558.0
# 3188      999482                 -2.051910  ...                0         -204.0
# 3189      999880                  0.756190  ...                0            NaN
# 3190      999990                 -1.049540  ...                0            NaN
#
# ...

# %%
df_all = df_all.merge(labs, on='subject_id', how='left')
df_all
# Out:
#       subject_id  ...  Neutrophils_Duration
# 0            329  ...                   NaN
# 1            649  ...                   NaN
# 2            708  ...                   NaN
# 3           1234  ...                   NaN
# 4           2492  ...                   NaN
# ...          ...  ...                   ...
# 3186      998894  ...                  24.0
# 3187      998908  ...                  68.0
# 3188      999482  ...                  66.0
# 3189      999880  ...                   NaN
# 3190      999990  ...                  82.0
#
# [3191 rows x 250 columns]

# %%
df_all = df_all.merge(vital, on='subject_id', how='left')
df_all
# Out:
#       subject_id  slope_following_9_months  ...  Weight_kg_slope  BMI_slope
# 0            329                 -1.268194  ...        -0.088889  -0.035833
# 1            649                 -0.922323  ...         0.011475   0.004656
# 2            708                 -0.543512  ...        -0.108791  -0.031960
# 3           1234                 -0.915388  ...         0.021429   0.006997
# 4           2492                 -0.598754  ...         0.000000   0.000000
# ...          ...                       ...  ...              ...        ...
# 3186      998894                 -1.504474  ...         0.000000   0.000000
# 3187      998908                 -0.856443  ...         0.095588   0.031212
# 3188      999482                 -2.051910  ...        -0.037500  -0.011321
# 3189      999880                  0.756190  ...        -0.007143  -0.002543
# 3190      999990                 -1.049540  ...        -0.001471  -0.000574
#
# [3191 rows x 301 columns]

# %%
df_all = df_all.merge(Riluzole, on='subject_id', how='left')
df_all
# Out:
#       subject_id  ...  Riluzole_use_Delta
# 0            329  ...                 NaN
# 1            649  ...                 0.0
# 2            708  ...                 NaN
# 3           1234  ...                 0.0
# 4           2492  ...                 NaN
# ...          ...  ...                 ...
# 3186      998894  ...                 0.0
# 3187      998908  ...                 0.0
# 3188      999482  ...                 0.0
# 3189      999880  ...                 NaN
# 3190      999990  ...                 0.0
#
# [3191 rows x 303 columns]

# %%
df_all = df_all.merge(fvc, on='subject_id', how='left')
df_all
# Out:
#       subject_id  ...  fvc_liters_SlopeDeltaSlope
# 0            329  ...                   -0.000253
# 1            649  ...                    0.000110
# 2            708  ...                   -0.000251
# 3           1234  ...                   -0.002184
# 4           2492  ...                    0.000000
# ...          ...  ...                         ...
# 3186      998894  ...                    0.000000
# 3187      998908  ...                    0.000793
# 3188      999482  ...                   -0.000418
# 3189      999880  ...                    0.000095
# 3190      999990  ...                   -0.000394
#
# [3191 rows x 325 columns]

# %%
# df_all = df_all.merge(svc, on='subject_id', how='left')
# df_all

# %% [markdown]
# # Split data

# %%
train = df_all.sample(frac=0.67, random_state=42)
train
# Out:
#       subject_id  ...  fvc_liters_SlopeDeltaSlope
# 1029      323088  ...                    0.000000
# 1001      312890  ...                   -0.000053
# 785       239612  ...                   -0.000471
# 411       124452  ...                    0.000392
# 1105      344950  ...                   -0.000232
# ...          ...  ...                         ...
# 2679      845493  ...                    0.000729
# 3132      982255  ...                    0.000105
# 1879      593471  ...                   -0.000493
# 2997      943579  ...                    0.000135
# 1203      377423  ...                    0.000043
#
# [2138 rows x 325 columns]

# %%
training = train.sample(frac=0.8, random_state=42)
training
# Out:
#       subject_id  ...  fvc_liters_SlopeDeltaSlope
# 1752      553099  ...                    0.003122
# 25          8471  ...                    0.000411
# 1697      534458  ...                   -0.000520
# 742       225766  ...                    0.000557
# 544       161271  ...                   -0.000075
# ...          ...  ...                         ...
# 1441      445636  ...                    0.000190
# 2783      879802  ...                    0.000389
# 2115      661349  ...                    0.000000
# 1128      355639  ...                   -0.000055
# 1953      612378  ...                   -0.000038
#
# [1710 rows x 325 columns]

# %%
test = train.drop(training.index)
test
# Out:
#       subject_id  ...  fvc_liters_SlopeDeltaSlope
# 1001      312890  ...                   -0.000053
# 134        38898  ...                   -0.000246
# 1423      441498  ...                   -0.000173
# 2236      701123  ...                    0.000596
# 756       230653  ...                   -0.000100
# ...          ...  ...                         ...
# 428       129520  ...                   -0.000230
# 2079      651076  ...                   -0.000222
# 1724      542313  ...                    0.000000
# 1086      340458  ...                    0.000169
# 147        45249  ...                   -0.000095
#
# [428 rows x 325 columns]

# %%
validation = df_all.drop(train.index)
validation
# Out:
#       subject_id  ...  fvc_liters_SlopeDeltaSlope
# 1            649  ...                    0.000110
# 3           1234  ...                   -0.002184
# 4           2492  ...                    0.000000
# 5           2956  ...                   -0.000332
# 9           3870  ...                   -0.000410
# ...          ...  ...                         ...
# 3168      993900  ...                    0.000564
# 3171      994973  ...                    0.000361
# 3174      995546  ...                   -0.004375
# 3176      996401  ...                   -0.000515
# 3181      997276  ...                    0.000576
#
# [1053 rows x 325 columns]

# %%
# X = df_all.drop(columns='slope for 3-12')
# y = df_all['slope for 3-12']

# %% [markdown]
# #Save data

# %%
#save to CSV in google drive
train.to_csv('/content/drive/MyDrive/ML Project/Cleaned data/Train-Test/train.csv')
training.to_csv('/content/drive/MyDrive/ML Project/Cleaned data/Train-Test/training.csv')
test.to_csv('/content/drive/MyDrive/ML Project/Cleaned data/Train-Test/testing.csv')
validation.to_csv('/content/drive/MyDrive/ML Project/Cleaned data/Validation/validation.csv')

# %% [markdown]
# # Work on training set

# %%
#train.to_csv('/content/drive/MyDrive/ML Project/Cleaned data/Train-Test/temp_train.csv')

# %%
#training.to_csv('/content/drive/MyDrive/ML Project/Cleaned data/Train-Test/temp_training.csv')

# %% [markdown]
# ## Impute missing data
# Do it separately for training, testing and validation set

# %% [markdown]
# ### Missing data information

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1710 entries, 1752 to 1953
# Columns: 322 entries, subject_id to fvc_liters_SlopeDeltaSlope
# dtypes: float64(303), int64(19)
# memory usage: 4.2 MB

# %%
# summarize the number of rows with missing values for each column
for i in range(training.shape[1]):
	# count number of rows with missing values
	n_miss = training.iloc[:,i].isnull().sum() 
	perc = n_miss / training.shape[0] * 100
	print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 0 (0.0%)
# > 3, Missing: 0 (0.0%)
# > 4, Missing: 0 (0.0%)
# > 5, Missing: 0 (0.0%)
# > 6, Missing: 0 (0.0%)
# > 7, Missing: 0 (0.0%)
# > 8, Missing: 0 (0.0%)
# > 9, Missing: 0 (0.0%)
# > 10, Missing: 0 (0.0%)
# > 11, Missing: 0 (0.0%)
# > 12, Missing: 0 (0.0%)
# > 13, Missing: 794 (46.4%)
# > 14, Missing: 860 (50.3%)
# > 15, Missing: 0 (0.0%)
# > 16, Missing: 1478 (86.4%)
# > 17, Missing: 1478 (86.4%)
# > 18, Missing: 1478 (86.4%)
# > 19, Missing: 1478 (86.4%)
# > 20, Missing: 1478 (86.4%)
# > 21, Missing: 1478 (86.4%)
# > 22, Missing: 1478 (86.4%)
# > 23, Missing: 1478 (86.4%)
# > 24, Missing: 1478 (86.4%)
# > 25, Missing: 1478 (86.4%)
# > 26, Missing: 0 (0.0%)
# > 27, Missing: 946 (55.3%)
# > 28, Missing: 0 (0.0%)
# > 29, Missing: 0 (0.0%)
# > 30, Missing: 0 (0.0%)
# > 31, Missing: 0 (0.0%)
# > 32, Missing: 0 (0.0%)
# > 33, Missing: 0 (0.0%)
# > 34, Missing: 0 (0.0%)
# > 35, Missing: 0 (0.0%)
# ...

# %%
# %%capture
# activate R magic to use R in this notebook
# https://ipython.org/ipython-doc/2/config/extensions/rmagic.html
# %load_ext rpy2.ipython

# %% [markdown]
# ###Use median for continuous variables

# %%
# %%R
# #impute missing using median/mean for continuous
# cont_ind<-c(14,15,28,39:300,302)
# train_imp<-training
# for (i in 1:length(cont_ind)){
#   #i=1
#   coli<-cont_ind[i]
#   train_imp[,coli]<-as.numeric(train_imp[,coli])
#
#   imputei<-median(train_imp[,coli],na.rm=T)
#   train_imp[,coli]<-ifelse(is.na(train_imp[,coli]),imputei,train_imp[,coli])
#
# }

# %% [markdown]
# ###Impute 0 for neurodisease history, family history and Riluzole use.
#
# ###No missing categorical data (missing race included as a group, no NA in race)

# %%
# %%R
# for (i in c(17:26,301)){
#   train_imp[,i]<-ifelse(is.na(train_imp[,i]),0,train_imp[,i])
#   print(table(is.na(train_imp[,i])))
# }
# Out:
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138
#
# FALSE
#  2138

# %% [markdown]
# ###kNN
#
# https://machinelearningmastery.com/knn-imputation-for-missing-values-in-machine-learning/

# %%
# knn imputation transform for the horse colic dataset
from numpy import isnan
from pandas import read_csv
from sklearn.impute import KNNImputer
# load dataset
url = '/content/drive/MyDrive/ML Project/Cleaned data/Train-Test/temp_train.csv'
dataframe = read_csv(url, header=None, na_values='?')
dataframe.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-5eb8f30b1613> in <module>()
#       5 # load dataset
#       6 url = '/content/drive/MyDrive/ML Project/Cleaned data/Train-Test/temp_train.csv'
# ----> 7 dataframe = read_csv(url, header=None, na_values='?')
#       8 dataframe.info()
#
# ...

# %%
# split into input and output elements
data = dataframe.values
data = data[1:,1:].astype(np.float)
ix = [i for i in range(data.shape[1]) if i != 6]
X, y = data[:, ix], data[:, 6]

# print total missing
print('Missing: %d' % sum(isnan(X).flatten()))
# define imputer
imputer = KNNImputer()
# fit on the dataset
imputer.fit(X)
# transform the dataset
Xtrans = imputer.transform(X)
# print total missing
print('Missing: %d' % sum(isnan(Xtrans).flatten()))

# %%
Xtrans

# %% [markdown]
# KNNImputer and Different Number of Neighbors
# The key hyperparameter for the KNN algorithm is k; that controls the number of nearest neighbors that are used to contribute to a prediction.
#
# It is good practice to test a suite of different values for k.
#
# The example below evaluates model pipelines and compares odd values for k from 1 to 21.

# %%
# compare knn imputation strategies for the horse colic dataset
from numpy import mean
from numpy import std
from pandas import read_csv
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import KNNImputer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from matplotlib import pyplot
# load dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/horse-colic.csv'
dataframe = read_csv(url, header=None, na_values='?')
# split into input and output elements
data = dataframe.values
ix = [i for i in range(data.shape[1]) if i != 23]
X, y = data[:, ix], data[:, 23]
# evaluate each strategy on the dataset
results = list()
strategies = [str(i) for i in [1,3,5,7,9,15,18,21]]
for s in strategies:
	# create the modeling pipeline
	pipeline = Pipeline(steps=[('i', KNNImputer(n_neighbors=int(s))), ('m', RandomForestClassifier())])
	# evaluate the model
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	scores = cross_val_score(pipeline, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
	# store results
	results.append(scores)
	print('>%s %.3f (%.3f)' % (s, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=strategies, showmeans=True)
pyplot.show()

# %%
#change above code
from numpy import isnan
from pandas import read_csv
from sklearn.impute import KNNImputer
# split into input and output elements
data = training.values
print(range(data.shape[1])) #342 col
ix = [i for i in range(data.shape[1]) if i not in [0,5]] #0 is subject id, 6th column is outcome(index=5)
print(np.shape(ix)) #340
X, y = data[:, ix], data[:, 5]
# print total missing
print('Missing: %d' % sum(isnan(X).flatten()))

# %%
# define imputer
imputer = KNNImputer(n_neighbors=5)
# fit on the dataset
imputer.fit(X)
# transform the dataset
Xtrans = imputer.transform(X)
# print total missing
print('Missing: %d' % sum(isnan(Xtrans).flatten()))

# %%
np.shape(Xtrans) #320 cols
#Xtrans[0:10,322:340]

# %%
idcol=data[:,0]
imp_data=np.c_[idcol,Xtrans]
training_imp_knn=pd.DataFrame(np.c_[imp_data,y])
training_imp_knn

# %% [markdown]
# ##Explore relationship with outcome

# %% [markdown]
# ###Loess plots

# %%
# %%R
# #just a sample code here, I plan to run locally to generate all plots
# for (i in 1:length(cont_ind)){ #cont_ind: column location of all continuous variables
#   #i=1
#   coli<-cont_ind[i]
#   training[,coli]<-as.numeric(training[,coli])
#
#   pi<-ggplot(data=training,aes(x=training[,coli],y=slope_following_9_months))+geom_point(postion=position_dodge(2.5))+
#     geom_smooth(method="loess",formula='y~x')+theme_classic()+
#     theme(panel.grid = element_blank())+xlab(names(training)[coli])+ylab("Slope: 3 to 12 month")
#   print(pi)
# }

# %% [markdown]
# ###Simple linear regression

# %%
# %%R
# #also run locally due to large number of variables
# #sample codes for categorical variables-race and site of onset
# #omit white-reference group
# fit<-lm(slope_following_9_months~race_black+race_asiangrp+race_othergrps,data=training)
# summary(fit)

# %%
# %%R
# fit<-lm(slope_following_9_months~factor(SiteOfOnset),data=training)
# summary(fit)
